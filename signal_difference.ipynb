# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
from dark_emulator_public import dark_emulator
import os, sys, time, json, copy
import matplotlib.pyplot as plt
from collections import OrderedDict as od
from scipy.interpolate import InterpolatedUnivariateSpline as ius
from scipy.interpolate import interp2d, interp1d
from scipy.integrate import simps
from tqdm import tqdm
import hsc3x2pt
# Out:
# using dark_emulator at  /Users/sunao-mac/Documents/python_package/dark_emulator_public/dark_emulator/__init__.py

# %%
power_b1 = hsc3x2pt.power_b1_class()
# Out:
# initialize cosmo_class
# Initialize pklin emulator
# initialize propagator emulator
# Initialize sigma_d emulator
# initialize cross-correlation emulator
# initialize auto-correlation emulator
# Initialize sigmaM emulator
# initialize xinl emulator

# %% [markdown]
# ## Changes in model signal: single source

# %%
dirname = './single_source_ClY1'
x,y,y_dict,cov, pnames, param_fid, F = hsc3x2pt.getFisherMat(dirname, power_b1)
# Out:
# cov.shape = (72, 72), dim(data)=(72,)

# %%
v = np.diag(cov.get_full_covariance())**0.5

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
v_fid = y.get_signal()
plt.ylim(0.95, 1.05)
plt.plot(y_dict['omega_b'].get_signal()/v_fid, label=r'$\omega_b$')
plt.plot(y_dict['omega_c'].get_signal()/v_fid, label=r'$\omega_c$')
plt.plot(y_dict['Omega_de'].get_signal()/v_fid, label=r'$\Omega_{de}$')
plt.plot(y_dict['ns'].get_signal()/v_fid, label=r'$n_s$')
plt.plot(y_dict['sigma8'].get_signal()/v_fid,label=r'$\ln 10^{10}A_s$')
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
plt.ylim(0.95, 1.05)
plt.plot(y_dict['b1lowz'].get_signal()/y.get_signal())
plt.plot(y_dict['b1cmass1'].get_signal()/y.get_signal())
plt.plot(y_dict['b1cmass2'].get_signal()/y.get_signal())
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
#plt.ylim(0.99, 1.01)
plt.plot(y_dict['alphamaglowz'].get_signal()/y.get_signal())
plt.plot(y_dict['alphamagcmass1'].get_signal()/y.get_signal())
plt.plot(y_dict['alphamagcmass2'].get_signal()/y.get_signal())
#plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
plt.ylim(0.95, 1.05)
plt.plot(y_dict['dm'].get_signal()/y.get_signal())
plt.plot(y_dict['dzph'].get_signal()/y.get_signal())
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()

# %% [markdown]
# ## Changes in model signal: double source

# %%
dirname = './double_source_ClY1'
x,y,y_dict,cov, pnames, param_fid, F = hsc3x2pt.getFisherMat(dirname, power_b1)
# Out:
# cov.shape = (129, 129), dim(data)=(129,)

# %%
v = np.diag(cov.get_full_covariance())**0.5

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
v_fid = y.get_signal()
plt.ylim(0.95, 1.05)
plt.plot(y_dict['omega_b'].get_signal()/v_fid, label=r'$\omega_b$')
plt.plot(y_dict['omega_c'].get_signal()/v_fid, label=r'$\omega_c$')
plt.plot(y_dict['Omega_de'].get_signal()/v_fid, label=r'$\Omega_{de}$')
plt.plot(y_dict['ns'].get_signal()/v_fid, label=r'$n_s$')
plt.plot(y_dict['sigma8'].get_signal()/v_fid,label=r'$\ln 10^{10}A_s$')
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
plt.ylim(0.95, 1.05)
plt.plot(y_dict['b1lowz'].get_signal()/y.get_signal())
plt.plot(y_dict['b1cmass1'].get_signal()/y.get_signal())
plt.plot(y_dict['b1cmass2'].get_signal()/y.get_signal())
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
#plt.ylim(0.99, 1.01)
plt.plot(y_dict['alphamaglowz'].get_signal()/y.get_signal())
plt.plot(y_dict['alphamagcmass1'].get_signal()/y.get_signal())
plt.plot(y_dict['alphamagcmass2'].get_signal()/y.get_signal())
#plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()

# %%
plt.figure(figsize=(15,4))
#plt.yscale('log')
#plt.plot(y.get_signal(), color='k')
plt.ylim(0.95, 1.05)
#plt.plot(y_dict['dm1'].get_signal()/y.get_signal())
plt.plot(y_dict['dm2'].get_signal()/y.get_signal())
#plt.plot(y_dict['dzph1'].get_signal()/y.get_signal())
plt.plot(y_dict['dzph2'].get_signal()/y.get_signal())
plt.errorbar(np.arange(len(v)), np.ones(len(v)), v/v_fid, color='gray')
plt.axhline(1.0, color='k')
plt.show()
